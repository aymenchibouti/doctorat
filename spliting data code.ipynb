# %% [markdown]
# <a href="https://colab.research.google.com/github/aymenchibouti/doctorat/blob/main/spliting%20data%20code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# Load the dataset
file_path = 'log_train.csv'  # Replace 'your_file_path' with the actual file location
data = pd.read_csv(file_path)

# Splitting the data into 80% training and 20% testing
train_data, test_data = train_test_split(data, test_size=0.2, random_state=42)

# Exporting the testing data to a CSV file
test_data.to_csv('testing_data.csv', index=False)

print("Testing data saved to 'testing_data.csv'")
# Out:
# Testing data saved to 'testing_data.csv'

# %%
normalized
# Out:
#        enrollment_id  label  avg_chapter_delays  parallel_enrollments  \
# 0                 -1    0.0            0.398073              3.227128
# 1                 -1    1.0           -0.440306             -0.520783
# 2                 -1    1.0           -0.440306             -0.520783
# 3                 -1    0.0            0.859181              0.416194
# 4                 -1    0.0            0.426019             -0.520783
# ...              ...    ...                 ...                   ...
# 72390             -1    1.0           -0.440306              0.416194
# 72391             -1    1.0           -0.440306             -0.520783
# 72392             -1    1.0           -0.440306             -0.520783
# 72393             -1    1.0            4.757644              0.416194
# 72394             -1    1.0           -0.440306              0.416194
#
#        act_cnt_day_01  act_cnt_day_02  act_cnt_day_03  act_cnt_day_04  \
# ...
