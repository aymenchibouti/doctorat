# %% [markdown]
# <a href="https://colab.research.google.com/github/aymenchibouti/doctorat/blob/main/ANN_chatgpt.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# Load dataset from Keras
from tensorflow.keras.datasets import mnist

# Load the MNIST dataset
(X_train, y_train), (X_test, y_test) = mnist.load_data()

# Preprocess the data
# Flatten the images
X_train = X_train.reshape(X_train.shape[0], -1).astype('float32')
X_test = X_test.reshape(X_test.shape[0], -1).astype('float32')

# Normalize the pixel values to the range [0, 1]
X_train /= 255.0
X_test /= 255.0

# Convert class vectors to binary class matrices (one-hot encoding)
num_classes = 10
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# Split the training data into training and validation sets
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=42)

# Define the architecture of the neural network
model = keras.Sequential([
    layers.Dense(128, activation='relu', input_shape=(784,)),  # Input layer with 784 input features (flattened image)
    layers.Dense(64, activation='relu'),  # Hidden layer with 64 neurons and ReLU activation
    layers.Dense(num_classes, activation='softmax')  # Output layer with 10 neurons (number of classes) and softmax activation for multi-class classification
])

# Compile the model
model.compile(optimizer='adam',  # Optimizer: Adam
              loss='categorical_crossentropy',  # Loss function: Categorical cross-entropy
              metrics=['accuracy'])  # Evaluation metric: Accuracy

# Train the model
history = model.fit(X_train, y_train, epochs=10, batch_size=32, validation_data=(X_val, y_val))

# Evaluate the model on the test set
test_loss, test_acc = model.evaluate(X_test, y_test)
print('Test accuracy:', test_acc)
# Out:
# ...
# 11490434/11490434 [==============================] - 0s 0us/step
# Epoch 1/10
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.2606 - accuracy: 0.9245 - val_loss: 0.1403 - val_accuracy: 0.9570
# Epoch 2/10
# 1500/1500 [==============================] - 7s 5ms/step - loss: 0.1123 - accuracy: 0.9658 - val_loss: 0.1101 - val_accuracy: 0.9664
# Epoch 3/10
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.0772 - accuracy: 0.9768 - val_loss: 0.0935 - val_accuracy: 0.9725
# Epoch 4/10
# 1500/1500 [==============================] - 7s 5ms/step - loss: 0.0602 - accuracy: 0.9813 - val_loss: 0.0919 - val_accuracy: 0.9716
# Epoch 5/10
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.0467 - accuracy: 0.9853 - val_loss: 0.0900 - val_accuracy: 0.9746
# Epoch 6/10
# 1500/1500 [==============================] - 7s 5ms/step - loss: 0.0364 - accuracy: 0.9885 - val_loss: 0.1016 - val_accuracy: 0.9710
# Epoch 7/10
# ...

# %%
import matplotlib.pyplot as plt

# Train the model
history = model.fit(X_train, y_train, epochs=10, batch_size=32, validation_data=(X_val, y_val))

# Plot training and validation accuracy over epochs
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training and Validation Accuracy')
plt.legend()
plt.show()
# Out:
# Epoch 1/10
# 1500/1500 [==============================] - 13s 8ms/step - loss: 0.0142 - accuracy: 0.9954 - val_loss: 0.1225 - val_accuracy: 0.9728
# Epoch 2/10
# 1500/1500 [==============================] - 7s 5ms/step - loss: 0.0169 - accuracy: 0.9942 - val_loss: 0.1065 - val_accuracy: 0.9777
# Epoch 3/10
# 1500/1500 [==============================] - 7s 5ms/step - loss: 0.0136 - accuracy: 0.9956 - val_loss: 0.1247 - val_accuracy: 0.9755
# Epoch 4/10
# 1500/1500 [==============================] - 7s 4ms/step - loss: 0.0143 - accuracy: 0.9953 - val_loss: 0.1288 - val_accuracy: 0.9754
# Epoch 5/10
# 1500/1500 [==============================] - 7s 5ms/step - loss: 0.0105 - accuracy: 0.9966 - val_loss: 0.1195 - val_accuracy: 0.9758
# Epoch 6/10
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.0112 - accuracy: 0.9959 - val_loss: 0.1274 - val_accuracy: 0.9781
# Epoch 7/10
# ...

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# Load dataset from Keras
from tensorflow.keras.datasets import mnist

# Load the MNIST dataset
(X_train, y_train), (X_test, y_test) = mnist.load_data()

# Preprocess the data
# Flatten the images
X_train = X_train.reshape(X_train.shape[0], -1).astype('float32')
X_test = X_test.reshape(X_test.shape[0], -1).astype('float32')

# Normalize the pixel values to the range [0, 1]
X_train /= 255.0
X_test /= 255.0

# Convert class vectors to binary class matrices (one-hot encoding)
num_classes = 10
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# Split the training data into training and validation sets
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=42)

# Define the architecture of the neural network with Dropout regularization
model = keras.Sequential([
    layers.Dense(128, activation='relu', input_shape=(784,)),  # Input layer with 784 input features (flattened image)
    layers.Dropout(0.5),  # Dropout layer with 50% dropout rate
    layers.Dense(64, activation='relu'),  # Hidden layer with 64 neurons and ReLU activation
    layers.Dropout(0.5),  # Dropout layer with 50% dropout rate
    layers.Dense(num_classes, activation='softmax')  # Output layer with 10 neurons (number of classes) and softmax activation for multi-class classification
])

# Compile the model
model.compile(optimizer='adam',  # Optimizer: Adam
              loss='categorical_crossentropy',  # Loss function: Categorical cross-entropy
              metrics=['accuracy'])  # Evaluation metric: Accuracy

# Train the model
history = model.fit(X_train, y_train, epochs=10, batch_size=32, validation_data=(X_val, y_val))

# Evaluate the model on the test set
test_loss, test_acc = model.evaluate(X_test, y_test)
print('Test accuracy:', test_acc)
# Out:
# Epoch 1/10
# 1500/1500 [==============================] - 10s 6ms/step - loss: 0.6315 - accuracy: 0.8065 - val_loss: 0.2182 - val_accuracy: 0.9351
# Epoch 2/10
# 1500/1500 [==============================] - 12s 8ms/step - loss: 0.3434 - accuracy: 0.9035 - val_loss: 0.1716 - val_accuracy: 0.9506
# Epoch 3/10
# 1500/1500 [==============================] - 12s 8ms/step - loss: 0.2834 - accuracy: 0.9206 - val_loss: 0.1499 - val_accuracy: 0.9581
# Epoch 4/10
# 1500/1500 [==============================] - 7s 4ms/step - loss: 0.2577 - accuracy: 0.9266 - val_loss: 0.1304 - val_accuracy: 0.9613
# Epoch 5/10
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.2311 - accuracy: 0.9344 - val_loss: 0.1297 - val_accuracy: 0.9628
# Epoch 6/10
# 1500/1500 [==============================] - 7s 5ms/step - loss: 0.2250 - accuracy: 0.9369 - val_loss: 0.1206 - val_accuracy: 0.9638
# Epoch 7/10
# ...

# %%
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training and Validation Accuracy')
plt.legend()
plt.show()
